# %% [markdown]
# # WeatherPy
#  - Observed trend 1
#  - Observed trend 1
#  - Observed trend 1

# %%
import pandas as pd
import json
from config import api_key
from citipy import citipy
import requests
import matplotlib.pyplot as plt
import random

weather_url = 'http://api.openweathermap.org/data/2.5/weather?'

# %% [markdown]
# ## Generate List of Cities and Make API Calls

# %%
number_of_cities = 500
cities = []
city_dicts = []
while len(cities) < number_of_cities:
    rand_lat = random.uniform(-90, 90)
    rand_lon = random.uniform(-180, 180)
    city = citipy.nearest_city(rand_lat, rand_lon)
    if city not in cities:
        city_name = city.city_name.replace(' ', '')
        country_code = city.country_code
        city_query_string = f'{city_name},{country_code}'
        params = {'appid': api_key,
                  'q': city_query_string,
                  'units': 'imperial'
                 }
        response = requests.get(weather_url, params=params)
        if response.status_code == 200:
            response_data = response.json()
            temp = response_data['main']['temp']
            humidity = response_data['main']['humidity']
            cloudiness = response_data['clouds']['all']
            wind_speed =  response_data['wind']['speed']
            lat = response_data['coord']['lat']
            lon = response_data['coord']['lon']
            name = response_data['name']
            country = response_data['sys']['country']
            city_date = {'city': name, 'country': country, 'temp': temp,
                         'humidity': humidity, 'cloudiness': cloudiness,
                         'wind_speed': wind_speed, 'lat': lat, 'long': lon}
            city_dicts.append(city_date)
            cities.append(city)
            print('%i - %s, %s' % (len(cities), name, country))
        else:
            pass
    else:
        pass
temperature_df = pd.DataFrame(city_dicts)
temperature_df['humidity']
temperature_df['cloudiness']
temperature_df
# Out:
# 1 - Saint-Philippe, RE
# 2 - Ballina, IE
# 3 - Rikitea, PF
# 4 - Qaanaaq, GL
# 5 - Antalaha, MG
# 6 - Nantucket, US
# 7 - Thompson, CA
# 8 - Montepuez, MZ
# 9 - Waingapu, ID
# 10 - Majene, ID
# 11 - Sokolovyy, RU
# 12 - Butaritari, KI
# 13 - Amahai, ID
# 14 - Isangel, VU
# 15 - Albany, AU
# 16 - Araouane, ML
# 17 - Yellowknife, CA
# 18 - Torbay, CA
# 19 - Kemi, FI
# 20 - Kutum, SD
# 21 - Kapaa, US
# 22 - Arlit, NE
# 23 - Cuamba, MZ
# 24 - Dekar, BW
# 25 - Atuona, PF
# 26 - Tautira, PF
# 27 - Vanimo, PG
# 28 - Bonthe, SL
# 29 - Chumikan, RU
# 30 - Smirnykh, RU
# 31 - Yar-Sale, RU
# 32 - Padang, ID
# 33 - Tuktoyaktuk, CA
# 34 - Hermanus, ZA
# 35 - Bethel, US
# 36 - Saskylakh, RU
# 37 - Ushuaia, AR
# 38 - Kerema, PG
# 39 - Jamestown, SH
# 40 - Haicheng, CN
# 41 - Betioky, MG
# 42 - Tigil, RU
# 43 - Tasiilaq, GL
# 44 - Hobart, AU
# 45 - Georgetown, SH
# 46 - Bandarbeyla, SO
# 47 - Vaini, TO
# 48 - Alyangula, AU
# 49 - Schluchtern, DE
# 50 - Maymyo, MM
# 51 - Hilo, US
# 52 - Dikson, RU
# 53 - Aksha, RU
# 54 - Gao, ML
# 55 - Aktau, KZ
# 56 - Ahipara, NZ
# 57 - Necochea, AR
# 58 - Komsomolskiy, RU
# 59 - Kuching, MY
# 60 - Pangkalanbuun, ID
# 61 - Castro, CL
# 62 - Bluff, NZ
# 63 - Victoria, SC
# 64 - Nanortalik, GL
# 65 - Busselton, AU
# 66 - Hofn, IS
# 67 - Chalus, IR
# 68 - Panguipulli, CL
# 69 - Esperance, AU
# 70 - Khatanga, RU
# 71 - Carnarvon, AU
# 72 - Hithadhoo, MV
# 73 - Suluq, LY
# 74 - Tarko-Sale, RU
# 75 - Havre-Saint-Pierre, CA
# 76 - Mahebourg, MU
# 77 - Shiraz, IR
# 78 - Tuatapere, NZ
# 79 - Ozernovskiy, RU
# 80 - Kupino, RU
# 81 - Maragogi, BR
# 82 - Pangody, RU
# 83 - Tretten, NO
# 84 - Yucaipa, US
# 85 - Kirakira, SB
# 86 - Omsukchan, RU
# 87 - Dhemaji, IN
# 88 - Hasaki, JP
# 89 - Helong, CN
# 90 - Rockport, US
# 91 - Nome, US
# 92 - Meulaboh, ID
# 93 - Lagoa, PT
# 94 - Tiksi, RU
# 95 - Kalmunai, LK
# 96 - Nishihara, JP
# 97 - Mantua, CU
# 98 - Arona, ES
# 99 - Juarez, MX
# 100 - Sitka, US
# 101 - Socorro, US
# 102 - Hamilton, BM
# 103 - Davila, PH
# 104 - Ust-Kuyga, RU
# 105 - Waipawa, NZ
# 106 - Dubbo, AU
# 107 - Beidao, CN
# 108 - Gap, FR
# 109 - Glendive, US
# 110 - Warrnambool, AU
# 111 - Lebu, CL
# 112 - Cuajinicuilapa, MX
# 113 - Cherskiy, RU
# 114 - Minas, UY
# 115 - Upernavik, GL
# 116 - Riohacha, CO
# 117 - Zharkovskiy, RU
# 118 - Ambilobe, MG
# 119 - Saint-Augustin, CA
# 120 - Souillac, MU
# 121 - Lompoc, US
# 122 - Bathsheba, BB
# 123 - Umaria, IN
# 124 - Agnibilekrou, CI
# 125 - Beysehir, TR
# 126 - Paamiut, GL
# 127 - Karratha, AU
# 128 - Zhumadian, CN
# 129 - Sarmellek, HU
# 130 - Hargeysa, SO
# 131 - Madanapalle, IN
# 132 - Homer, US
# 133 - Severo-Kurilsk, RU
# 134 - Pevek, RU
# 135 - Hambantota, LK
# 136 - Schwerin, DE
# 137 - Ouesso, CG
# 138 - Igrim, RU
# 139 - Fatick, SN
# 140 - Dingle, IE
# 141 - Lookan, PH
# 142 - Hami, CN
# 143 - Constitucion, CL
# 144 - Gamba, GA
# 145 - Mahibadhoo, MV
# 146 - Boras, SE
# 147 - Cayenne, GF
# 148 - Kaputa, ZM
# 149 - Provideniya, RU
# 150 - Suure-Jaani, EE
# 151 - Cairns, AU
# 152 - Yerbogachen, RU
# 153 - Pathein, MM
# 154 - Shenjiamen, CN
# 155 - Ixtapa, MX
# 156 - Bredasdorp, ZA
# 157 - Erzin, RU
# 158 - Mackay, AU
# 159 - Kavieng, PG
# 160 - Vardo, NO
# 161 - Kruisfontein, ZA
# 162 - Laguna, BR
# 163 - Flinders, AU
# 164 - Mbala, ZM
# 165 - Same, TZ
# 166 - Avarua, CK
# 167 - Baiyin, CN
# 168 - Ostrovnoy, RU
# 169 - Kyra, RU
# 170 - Aykhal, RU
# 171 - Waitati, NZ
# 172 - Albanel, CA
# 173 - Port-Gentil, GA
# 174 - Xiuyan, CN
# 175 - Sirnak, TR
# 176 - Salinopolis, BR
# 177 - Dongsheng, CN
# 178 - Chokurdakh, RU
# 179 - Talnakh, RU
# 180 - Mangrol, IN
# 181 - Aklavik, CA
# 182 - Thinadhoo, MV
# 183 - Eregli, TR
# 184 - College, US
# 185 - Bireun, ID
# 186 - Geraldton, AU
# 187 - Nizhnevartovsk, RU
# 188 - Saint-Francois, GP
# 189 - Kilindoni, TZ
# 190 - Rawah, IQ
# 191 - Coquimbo, CL
# 192 - Sweetwater, US
# 193 - Micheweni, TZ
# 194 - Itacarambi, BR
# 195 - Condega, NI
# 196 - Huntsville, US
# 197 - Beringovskiy, RU
# 198 - Hualmay, PE
# 199 - Manta, EC
# 200 - Svetlaya, RU
# 201 - Radom, PL
# 202 - Caltagirone, IT
# 203 - Chuy, UY
# 204 - Zaysan, KZ
# 205 - Kameoka, JP
# 206 - Linden, GY
# 207 - Soe, ID
# 208 - Conde, BR
# 209 - Sudak, UA
# 210 - Laramie, US
# 211 - Katsuura, JP
# 212 - Petropavlovsk-Kamchatskiy, RU
# 213 - Turukhansk, RU
# 214 - Domoni, KM
# 215 - Sechura, PE
# 216 - Barranca, PE
# 217 - Lapua, FI
# 218 - Faanui, PF
# 219 - Dubti, ET
# 220 - Kiama, AU
# 221 - Taoudenni, ML
# 222 - Coihaique, CL
# 223 - Kahului, US
# 224 - Birmitrapur, IN
# 225 - Agadir, MA
# 226 - Nizwa, OM
# 227 - Matagami, CA
# 228 - Weston, US
# 229 - Bengkulu, ID
# 230 - Sangar, RU
# 231 - Ust-Tsilma, RU
# 232 - Klaksvik, FO
# 233 - Itacare, BR
# 234 - Timmins, CA
# 235 - Longyearbyen, SJ
# 236 - Choix, MX
# 237 - Luderitz, NA
# 238 - Ayacucho, PE
# 239 - Canmore, CA
# 240 - Banjar, ID
# 241 - Wamba, CD
# 242 - Kapit, MY
# 243 - Barrow, US
# 244 - Mogwase, ZA
# 245 - Lavrentiya, RU
# 246 - Sesheke, ZM
# 247 - Balabac, PH
# 248 - Kodiak, US
# 249 - Nushki, PK
# 250 - Maraa, BR
# 251 - Narsaq, GL
# 252 - Ust-Omchug, RU
# 253 - Wanaka, NZ
# 254 - Nampa, US
# 255 - Kavaratti, IN
# 256 - Farmington, US
# 257 - Raahe, FI
# 258 - Zyryanskoye, RU
# 259 - Cervo, ES
# 260 - Urusha, RU
# 261 - Weinan, CN
# 262 - Guarapari, BR
# 263 - Okhotsk, RU
# 264 - Novooleksiyivka, UA
# 265 - Tarakan, ID
# 266 - Tura, RU
# 267 - Kidal, ML
# 268 - Parakan, ID
# 269 - Vao, NC
# 270 - Christchurch, NZ
# 271 - Camana, PE
# 272 - Roald, NO
# 273 - Leningradskiy, RU
# 274 - Okha, IN
# 275 - Shu, KZ
# 276 - Barra, BR
# 277 - Baykit, RU
# 278 - Maluso, PH
# 279 - Xuanzhou, CN
# 280 - Sivas, TR
# 281 - Sambava, MG
# 282 - Shimoda, JP
# 283 - Rawson, AR
# 284 - Touros, BR
# 285 - Champerico, GT
# 286 - Teacapan, MX
# 287 - Destin, US
# 288 - Kokopo, PG
# 289 - Iqaluit, CA
# 290 - Morogoro, TZ
# 291 - Vaitape, PF
# 292 - Loei, TH
# 293 - Cajabamba, PE
# 294 - Merauke, ID
# 295 - Samarai, PG
# 296 - Dhidhdhoo, MV
# 297 - Fairbanks, US
# 298 - Hornbaek, DK
# 299 - Porbandar, IN
# 300 - Maamba, ZM
# 301 - Bloomfield, US
# 302 - Wagar, SD
# 303 - Barillas, GT
# 304 - Bambanglipuro, ID
# 305 - Marawi, SD
# 306 - Christiansfeld, DK
# 307 - Panacan, PH
# 308 - Whitefish, US
# 309 - Muli, MV
# 310 - Axim, GH
# 311 - Olinala, MX
# 312 - Masvingo, ZW
# 313 - Mitsamiouli, KM
# 314 - Teterow, DE
# 315 - Recea, RO
# 316 - Togur, RU
# 317 - Freeport, US
# 318 - Kothi, IN
# 319 - Lulea, SE
# 320 - Kieta, PG
# 321 - Dancheng, CN
# 322 - Palmerston, AU
# 323 - Naze, JP
# 324 - Sinnamary, GF
# 325 - Beipiao, CN
# 326 - Srandakan, ID
# 327 - Hachinohe, JP
# 328 - Sigayevo, RU
# 329 - Sept-Iles, CA
# 330 - Sabang, ID
# 331 - Linxia, CN
# 332 - Amga, RU
# 333 - Pedernales, DO
# 334 - Mecca, SA
# 335 - Kazanskaya, RU
# 336 - Goure, NE
# 337 - Cidreira, BR
# 338 - Cinisi, IT
# 339 - Tessalit, ML
# 340 - Mana, GF
# 341 - Anadyr, RU
# 342 - Kloulklubed, PW
# 343 - Pyaozerskiy, RU
# 344 - Batagay, RU
# 345 - Harper, LR
# 346 - Segovia, ES
# 347 - Sotnikovo, RU
# 348 - Douglas, US
# 349 - Tromso, NO
# 350 - Hays, US
# 351 - Kropotkin, RU
# 352 - Batagay-Alyta, RU
# 353 - Araxa, BR
# 354 - Jilib, SO
# 355 - Chengde, CN
# 356 - Progreso, MX
# 357 - Xiaoweizhai, CN
# 358 - Sabha, LY
# 359 - Camocim, BR
# 360 - Ambanja, MG
# 361 - Alibag, IN
# 362 - Vestmannaeyjar, IS
# 363 - Peniche, PT
# 364 - Kashi, CN
# 365 - Portland, AU
# 366 - Karlovo, BG
# 367 - Alofi, NU
# 368 - Sistranda, NO
# 369 - Cadiz, ES
# 370 - Irtyshskiy, RU
# 371 - Alvaraes, BR
# 372 - Muros, ES
# 373 - Chivay, PE
# 374 - Gannan, CN
# 375 - Bubaque, GW
# 376 - Risod, IN
# 377 - Mpika, ZM
# 378 - Neiafu, TO
# 379 - Log, RU
# 380 - Springville, US
# 381 - Jucuapa, SV
# 382 - Buraydah, SA
# 383 - Vrangel, RU
# 384 - Payakumbuh, ID
# 385 - Shuyskoye, RU
# 386 - Kalmar, SE
# 387 - Coahuayana, MX
# 388 - Bulawayo, ZW
# 389 - Assis, BR
# 390 - Brooks, CA
# 391 - Mariinsk, RU
# 392 - Sorland, NO
# 393 - Mahajanga, MG
# 394 - Kollo, NE
# 395 - Alameda, US
# 396 - Krasnoyarskiy, RU
# 397 - Ilulissat, GL
# 398 - Kalabo, ZM
# 399 - Buala, SB
# 400 - Qinhuangdao, CN
# 401 - Salalah, OM
# 402 - Hovd, MN
# 403 - Maldonado, UY
# 404 - Kasongo-Lunda, CD
# 405 - Fare, PF
# 406 - Damavand, IR
# 407 - Trofaiach, AT
# 408 - Goya, AR
# 409 - Fortuna, US
# 410 - Boysun, UZ
# 411 - Sorong, ID
# 412 - Tanda, CI
# 413 - Kapolnasnyek, HU
# 414 - Boguchany, RU
# 415 - Parrita, CR
# 416 - Orcopampa, PE
# 417 - Dakar, SN
# 418 - Rezh, RU
# 419 - Navahrudak, BY
# 420 - Vidalia, US
# 421 - Husavik, IS
# 422 - Galesong, ID
# 423 - Qixia, CN
# 424 - Kharabali, RU
# 425 - Adrar, DZ
# 426 - Zhanaozen, KZ
# 427 - Frolovo, RU
# 428 - Lorengau, PG
# 429 - Nouadhibou, MR
# 430 - Khor, RU
# 431 - Laukaa, FI
# 432 - Ola, RU
# 433 - Mandalgovi, MN
# 434 - Vigrestad, NO
# 435 - Zarautz, ES
# 436 - Melhus, NO
# 437 - Iskilip, TR
# 438 - Pascagoula, US
# 439 - Orlik, RU
# 440 - Guilin, CN
# 441 - Vizinga, RU
# 442 - Beaverlodge, CA
# 443 - Aguimes, ES
# 444 - Abbeville, US
# 445 - Makokou, GA
# 446 - Kenai, US
# 447 - Seydi, TM
# 448 - Atar, MR
# 449 - Pangnirtung, CA
# 450 - Dinguiraye, GN
# 451 - Aquiraz, BR
# 452 - Egvekinot, RU
# 453 - Suoyarvi, RU
# 454 - Koumac, NC
# 455 - Yumaguzino, RU
# 456 - Zaozerne, UA
# 457 - Rabaul, PG
# 458 - Bucerias, MX
# 459 - Rangapara, IN
# 460 - Wanning, CN
# 461 - Karamadai, IN
# 462 - Natal, BR
# 463 - Jimani, DO
# 464 - Pingliang, CN
# 465 - Verkhoyansk, RU
# 466 - Yulara, AU
# 467 - Tawang, IN
# 468 - Ntungamo, UG
# 469 - Camapua, BR
# 470 - Eureka, US
# 471 - Tarauaca, BR
# 472 - Magan, RU
# 473 - Namibe, AO
# 474 - Broome, AU
# 475 - Ibirite, BR
# 476 - Planaltina, BR
# 477 - Rawlins, US
# 478 - Tranas, SE
# 479 - Vostok, RU
# 480 - Supaul, IN
# 481 - Ancud, CL
# 482 - Mpraeso, GH
# 483 - Chitrakonda, IN
# 484 - Monywa, MM
# 485 - Rudnogorsk, RU
# 486 - Juneau, US
# 487 - Chiscas, CO
# 488 - Orel, RU
# 489 - Saint-Joseph, RE
# 490 - Teguise, ES
# 491 - Muisne, EC
# 492 - Forestville, CA
# 493 - Sakaiminato, JP
# 494 - Lianga, PH
# 495 - Tiznit, MA
# 496 - Ortakoy, TR
# 497 - Sumbe, AO
# 498 - Srednekolymsk, RU
# 499 - Talara, PE
# 500 - Bonavista, CA
#                city  cloudiness country  humidity    lat    long   temp  \
# 0    Saint-Philippe          75      RE        74 -21.36   55.77  81.63
# 1           Ballina         100      IE       100  54.12   -9.17  42.16
# 2           Rikitea          12      PF       100 -23.12 -134.97  72.94
# 3           Qaanaaq          48      GL       100  77.48  -69.36  -4.33
# 4          Antalaha           0      MG        73 -14.90   50.28  81.94
# 5         Nantucket           1      US        73  41.28  -70.10  35.38
# 6          Thompson          90      CA        72  55.74  -97.86  10.40
# 7         Montepuez           0      MZ        59 -13.13   39.00  82.75
# 8          Waingapu          68      ID       100  -9.66  120.26  77.89
# 9            Majene          56      ID        98  -3.54  118.97  83.87
# 10        Sokolovyy           0      RU        80  51.57   45.83  30.20
# 11       Butaritari          92      KI       100   3.07  172.79  81.80
# 12           Amahai          12      ID       100  -3.33  128.92  84.10
# 13          Isangel          12      VU       100 -19.55  169.27  74.65
# 14           Albany          88      AU        92 -35.02  117.89  66.23
# 15         Araouane          92      ML        17  18.90   -3.53  59.93
# 16      Yellowknife          20      CA        75  62.46 -114.35 -14.81
# 17           Torbay          90      CA       100  47.67  -52.73  39.20
# 18             Kemi          90      FI        92  65.74   24.56  26.60
# 19            Kutum           0      SD        30  14.20   24.67  71.95
# 20            Kapaa          90      US        94  22.08 -159.32  72.43
# 21            Arlit           8      NE        52  18.74    7.39  61.28
# 22           Cuamba          48      MZ        71 -14.80   36.54  76.99
# 23            Dekar           0      BW        18 -21.53   21.93  67.58
# 24           Atuona          92      PF       100  -9.80 -139.03  77.26
# 25          Tautira          75      PF        74 -17.73 -149.15  80.60
# 26           Vanimo           8      PG       100  -2.67  141.30  85.00
# 27           Bonthe           0      SL        98   7.53  -12.51  76.67
# 28         Chumikan          20      RU       100  54.72  135.31  -1.81
# 29         Smirnykh          76      RU        79  49.75  142.83  15.02
# ..              ...         ...     ...       ...    ...     ...    ...
# 470        Tarauaca           0      BR        91  -8.16  -70.77  76.40
# 471           Magan           0      RU        74  62.11  129.53 -23.81
# 472          Namibe           0      AO       100 -15.20   12.15  69.92
# 473          Broome           8      AU        62 -17.97  122.23  87.80
# 474         Ibirite           0      BR        68 -20.02  -44.06  70.77
# 475      Planaltina           0      BR        93 -15.45  -47.61  64.40
# 476         Rawlins          90      US        85  41.79 -107.24  23.68
# 477          Tranas          92      SE        93  58.04   14.98  40.39
# 478          Vostok          44      RU        60  46.49  135.88   6.56
# 479          Supaul          32      IN        52  26.12   86.60  83.96
# 480           Ancud          64      CL        90 -41.87  -73.82  40.13
# 481         Mpraeso          32      GH        98   6.59   -0.73  71.72
# 482     Chitrakonda          48      IN        90  18.12   82.08  79.28
# 483          Monywa           0      MM        68  22.12   95.13  88.01
# 484      Rudnogorsk          92      RU       100  57.26  103.75  11.29
# 485          Juneau          90      US       100  58.30 -134.42  29.30
# 486         Chiscas          48      CO        97   6.55  -72.50  52.24
# 487            Orel          92      RU        96  52.97   36.08  31.76
# 488    Saint-Joseph          75      RE        74 -21.37   55.62  81.64
# 489         Teguise          12      ES       100  29.06  -13.56  64.84
# 490          Muisne          48      EC        96   0.60  -80.03  67.90
# 491     Forestville          90      CA        73  48.74  -69.08  23.00
# 492     Sakaiminato          75      JP        81  35.55  133.23  50.00
# 493          Lianga          64      PH        81   8.63  126.09  85.63
# 494          Tiznit          36      MA        79  29.58   -9.50  41.08
# 495         Ortakoy           0      TR        80  38.74   34.04  35.60
# 496           Sumbe           0      AO        96 -11.21   13.84  72.71
# 497   Srednekolymsk          80      RU        82  67.45  153.68  -2.13
# 498          Talara           8      PE        93  -4.58  -81.27  60.02
# 499       Bonavista          92      CA        99  48.65  -53.11  40.76
#
#      wind_speed
# 0          5.82
# 1          2.59
# 2         21.23
# 3          8.52
# 4          4.72
# 5          5.82
# 6         12.75
# 7          4.90
# 8          4.12
# 9          9.37
# 10        11.18
# 11         5.61
# 12         3.22
# 13        11.32
# 14         6.91
# 15         8.52
# 16         9.17
# 17        18.34
# 18         9.17
# 19         6.29
# 20         5.82
# 21         2.77
# 22         6.62
# 23         5.73
# 24        16.20
# 25         1.12
# 26        13.85
# 27         3.27
# 28         7.52
# 29         5.39
# ..          ...
# 470        3.22
# 471        2.24
# 472        3.38
# 473       14.99
# 474        6.93
# 475        3.36
# 476        9.17
# 477       10.29
# 478        4.83
# 479        4.12
# 480        2.89
# 481        4.05
# 482        3.60
# 483        7.81
# 484        3.83
# 485        3.00
# 486        1.25
# 487        8.41
# 488        5.82
# 489        9.86
# 490        3.49
# 491       18.34
# 492        5.82
# 493        5.50
# 494        1.59
# 495        8.05
# 496        3.83
# 497        4.83
# 498        3.83
# 499       20.22
#
# [500 rows x 8 columns]

# %% [markdown]
# ## Create Scatter Plots

# %%
def create_latitude_scatter_plot(df, y_axis_col, y_axis_title):
    plt.style.use('ggplot')
    plt.scatter(df['lat'], df[y_axis_col])
    plt.title(f'{y_axis_title} vs. Latitude')
    plt.xlabel('Latitude')
    plt.ylabel(y_axis_title)
    plt.xlim(-90, 90)
    plt.xticks(range(-90, 91, 30))
    plt.show()

# %%
create_latitude_scatter_plot(temperature_df, 'temp', 'Temperature (F)')

# %%
create_latitude_scatter_plot(temperature_df, 'humidity', 'Humidity (%)')

# %%
create_latitude_scatter_plot(temperature_df, 'cloudiness', 'Cloudiness (%)')

# %%
create_latitude_scatter_plot(temperature_df, 'wind_speed', 'Wind Speed (mph)')
